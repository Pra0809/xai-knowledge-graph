# %%
import torch
from pathlib import Path
from pykeen.triples import TriplesFactory
from pykeen.pipeline import pipeline

PROJECT_ROOT  = Path.home() / "xai-knowledge-graph"
TRIPLES_PATH  = PROJECT_ROOT / "data" / "triples" / "xai_kg.tsv"
MODEL_DIR     = PROJECT_ROOT / "models" / "rotate_tuned"

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {DEVICE}")
# Out:
# Using device: cuda

# %%
tf = TriplesFactory.from_path(str(TRIPLES_PATH))
training, testing, validation = tf.split([0.8, 0.1, 0.1], random_state=42)
print(f"Train: {training.num_triples:,} | Val: {validation.num_triples:,} | Test: {testing.num_triples:,}")
# Out:
# Train: 27,560 | Val: 3,446 | Test: 3,445

# %%
result = pipeline(
    training=training,
    testing=testing,
    validation=validation,
    model="RotatE",
    model_kwargs=dict(embedding_dim=128),       # 64 complex dimensions internally
    loss="NSSALoss",
    loss_kwargs=dict(margin=9.0, adversarial_temperature=1.0),
    training_kwargs=dict(num_epochs=200, batch_size=512),
    optimizer_kwargs=dict(lr=0.001),
    negative_sampler_kwargs=dict(num_negs_per_pos=64),
    evaluation_kwargs=dict(batch_size=256),
    device=DEVICE,
    random_seed=42,
)
print("\n✓ Training complete")
# Out:
# Training epochs on cuda:0:   0%|          | 0/200 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/3.44k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.36s seconds
# ✓ Training complete

# %%
key_metrics = result.metric_results.to_flat_dict()
print("=== RotatE_tuned Test-Set Metrics ===")
print(f"  Hits@1:       {key_metrics.get('both.realistic.hits_at_1', 0):.4f}")
print(f"  Hits@3:       {key_metrics.get('both.realistic.hits_at_3', 0):.4f}")
print(f"  Hits@10:      {key_metrics.get('both.realistic.hits_at_10', 0):.4f}")
print(f"  Mean Rank:    {key_metrics.get('both.realistic.arithmetic_mean_rank', 0):.2f}")
print(f"  MRR:          {key_metrics.get('both.realistic.inverse_harmonic_mean_rank', 0):.4f}")
# Out:
# === RotatE_tuned Test-Set Metrics ===
#   Hits@1:       0.1113
#   Hits@3:       0.2425
#   Hits@10:      0.3637
#   Mean Rank:    913.47
#   MRR:          0.1969

# %%
MODEL_DIR.mkdir(parents=True, exist_ok=True)
result.save_to_directory(str(MODEL_DIR))
print(f"RotatE model saved to {MODEL_DIR}")
# Out:
# INFO:pykeen.triples.triples_factory:Stored TriplesFactory(num_entities=18603, num_relations=4, create_inverse_triples=False, num_triples=27560, path="/slurm/homes/pchandra/xai-knowledge-graph/data/triples/xai_kg.tsv") to file:///slurm/homes/pchandra/xai-knowledge-graph/models/rotate_tuned/training_triples
# INFO:pykeen.pipeline.api:Saved to directory: /slurm/homes/pchandra/xai-knowledge-graph/models/rotate_tuned
# RotatE model saved to /slurm/homes/pchandra/xai-knowledge-graph/models/rotate_tuned
