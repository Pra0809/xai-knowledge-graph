# %%
import torch
from pathlib import Path
from pykeen.triples import TriplesFactory
from pykeen.pipeline import pipeline

PROJECT_ROOT = Path.home() / "xai-knowledge-graph"
TRIPLES_PATH = PROJECT_ROOT / "data" / "triples" / "xai_kg.tsv"
MODEL_DIR    = PROJECT_ROOT / "models" / "transe_basline"

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {DEVICE}")
print(f"Triples file:  {TRIPLES_PATH}")
# Out:
# Using device: cuda
# Triples file:  /slurm/homes/pchandra/xai-knowledge-graph/data/triples/xai_kg.tsv

# %%
tf = TriplesFactory.from_path(str(TRIPLES_PATH))
print(f"Loaded {tf.num_triples:,} triples")
print(f"  Entities:  {tf.num_entities:,}")
print(f"  Relations: {tf.num_relations}")

# 80/10/10 split for training, validation, test
training, testing, validation = tf.split([0.8, 0.1, 0.1], random_state=42)
print(f"\nSplit sizes:")
print(f"  Train:      {training.num_triples:,}")
print(f"  Validation: {validation.num_triples:,}")
print(f"  Test:       {testing.num_triples:,}")
# Out:
# Loaded 34,451 triples
#   Entities:  18,603
#   Relations: 4
#
# Split sizes:
#   Train:      27,560
#   Validation: 3,446
#   Test:       3,445

# %%
result = pipeline(
    training=training,
    testing=testing,
    validation=validation,
    model="TransE",
    loss="MarginRankingLoss",
    loss_kwargs=dict(margin=9.0),
    model_kwargs=dict(embedding_dim=128),
    training_kwargs=dict(num_epochs=100, batch_size=512),
    optimizer_kwargs=dict(lr=0.001),
    negative_sampler_kwargs=dict(num_negs_per_pos=10),
    evaluation_kwargs=dict(batch_size=256),
    device=DEVICE,
    random_seed=42,
)
print("\n✓ Training complete")
# Out:
# Training epochs on cuda:0:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/54.0 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/3.44k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.35s seconds
# ✓ Training complete

# %%
metrics_df = result.metric_results.to_df()
print(metrics_df.to_string())

# Pull out the key headline metrics
key_metrics = result.metric_results.to_flat_dict()
print(f"\n=== TransE Test-Set Metrics ===")
print(f"  Hits@1:       {key_metrics.get('both.realistic.hits_at_1', 0):.4f}")
print(f"  Hits@3:       {key_metrics.get('both.realistic.hits_at_3', 0):.4f}")
print(f"  Hits@10:      {key_metrics.get('both.realistic.hits_at_10', 0):.4f}")
print(f"  Mean Rank:    {key_metrics.get('both.realistic.arithmetic_mean_rank', 0):.2f}")
print(f"  MRR:          {key_metrics.get('both.realistic.inverse_harmonic_mean_rank', 0):.4f}")
# Out:
#      Side    Rank_type                               Metric         Value
# 0    head   optimistic                   harmonic_mean_rank  1.071707e+01
# 1    tail   optimistic                   harmonic_mean_rank  2.886267e+00
# 2    both   optimistic                   harmonic_mean_rank  4.547755e+00
# 3    head    realistic                   harmonic_mean_rank  1.071707e+01
# 4    tail    realistic                   harmonic_mean_rank  2.886266e+00
# 5    both    realistic                   harmonic_mean_rank  4.547754e+00
# 6    head  pessimistic                   harmonic_mean_rank  1.071707e+01
# 7    tail  pessimistic                   harmonic_mean_rank  2.886267e+00
# 8    both  pessimistic                   harmonic_mean_rank  4.547755e+00
# 9    head   optimistic                  geometric_mean_rank  3.453281e+02
# 10   tail   optimistic                  geometric_mean_rank  8.888901e+00
# 11   both   optimistic                  geometric_mean_rank  5.540385e+01
# 12   head    realistic                  geometric_mean_rank  3.453286e+02
# 13   tail    realistic                  geometric_mean_rank  8.888907e+00
# 14   both    realistic                  geometric_mean_rank  5.540389e+01
# 15   head  pessimistic                  geometric_mean_rank  3.453288e+02
# 16   tail  pessimistic                  geometric_mean_rank  8.888918e+00
# 17   both  pessimistic                  geometric_mean_rank  5.540396e+01
# 18   head   optimistic   adjusted_geometric_mean_rank_index  9.479140e-01
# 19   tail   optimistic   adjusted_geometric_mean_rank_index  9.988475e-01
# 20   both   optimistic   adjusted_geometric_mean_rank_index  9.919117e-01
# 21   head    realistic   adjusted_geometric_mean_rank_index  9.479140e-01
# 22   tail    realistic   adjusted_geometric_mean_rank_index  9.988475e-01
# 23   both    realistic   adjusted_geometric_mean_rank_index  9.919117e-01
# 24   head  pessimistic   adjusted_geometric_mean_rank_index  9.479139e-01
# 25   tail  pessimistic   adjusted_geometric_mean_rank_index  9.988475e-01
# 26   both  pessimistic   adjusted_geometric_mean_rank_index  9.919117e-01
# 27   head   optimistic  adjusted_inverse_harmonic_mean_rank  9.278488e-02
# 28   tail   optimistic  adjusted_inverse_harmonic_mean_rank  3.461024e-01
# 29   both   optimistic  adjusted_inverse_harmonic_mean_rank  2.194448e-01
# 30   head    realistic  adjusted_inverse_harmonic_mean_rank  9.278488e-02
# 31   tail    realistic  adjusted_inverse_harmonic_mean_rank  3.461025e-01
# 32   both    realistic  adjusted_inverse_harmonic_mean_rank  2.194448e-01
# 33   head  pessimistic  adjusted_inverse_harmonic_mean_rank  9.278488e-02
# 34   tail  pessimistic  adjusted_inverse_harmonic_mean_rank  3.461024e-01
# 35   both  pessimistic  adjusted_inverse_harmonic_mean_rank  2.194448e-01
# 36   head   optimistic            median_absolute_deviation  1.260212e+03
# 37   tail   optimistic            median_absolute_deviation  5.930409e+00
# 38   both   optimistic            median_absolute_deviation  4.892587e+01
# 39   head    realistic            median_absolute_deviation  1.260212e+03
# 40   tail    realistic            median_absolute_deviation  5.930409e+00
# 41   both    realistic            median_absolute_deviation  4.892587e+01
# 42   head  pessimistic            median_absolute_deviation  1.260212e+03
# 43   tail  pessimistic            median_absolute_deviation  5.930409e+00
# 44   both  pessimistic            median_absolute_deviation  4.892587e+01
# 45   head   optimistic         inverse_arithmetic_mean_rank  7.309790e-04
# 46   tail   optimistic         inverse_arithmetic_mean_rank  4.898441e-03
# 47   both   optimistic         inverse_arithmetic_mean_rank  1.272123e-03
# 48   head    realistic         inverse_arithmetic_mean_rank  7.309782e-04
# 49   tail    realistic         inverse_arithmetic_mean_rank  4.898431e-03
# 50   both    realistic         inverse_arithmetic_mean_rank  1.272122e-03
# 51   head  pessimistic         inverse_arithmetic_mean_rank  7.309776e-04
# 52   tail  pessimistic         inverse_arithmetic_mean_rank  4.898420e-03
# 53   both  pessimistic         inverse_arithmetic_mean_rank  1.272120e-03
# 54   head   optimistic  adjusted_arithmetic_mean_rank_index  8.479255e-01
# 55   tail   optimistic  adjusted_arithmetic_mean_rank_index  9.781555e-01
# 56   both   optimistic  adjusted_arithmetic_mean_rank_index  9.141458e-01
# 57   head    realistic  adjusted_arithmetic_mean_rank_index  8.479254e-01
# 58   tail    realistic  adjusted_arithmetic_mean_rank_index  9.781554e-01
# 59   both    realistic  adjusted_arithmetic_mean_rank_index  9.141457e-01
# 60   head  pessimistic  adjusted_arithmetic_mean_rank_index  8.479253e-01
# 61   tail  pessimistic  adjusted_arithmetic_mean_rank_index  9.781554e-01
# 62   both  pessimistic  adjusted_arithmetic_mean_rank_index  9.141456e-01
# 63   head   optimistic                             variance  3.339121e+06
# 64   tail   optimistic                             variance  4.295368e+05
# 65   both   optimistic                             variance  2.222984e+06
# 66   head    realistic                             variance  3.339124e+06
# 67   tail    realistic                             variance  4.295376e+05
# 68   both    realistic                             variance  2.222986e+06
# 69   head  pessimistic                             variance  3.339125e+06
# 70   tail  pessimistic                             variance  4.295384e+05
# 71   both  pessimistic                             variance  2.222988e+06
# 72   head   optimistic               z_arithmetic_mean_rank  8.612534e+01
# 73   tail   optimistic               z_arithmetic_mean_rank  9.943511e+01
# 74   both   optimistic               z_arithmetic_mean_rank  1.313489e+02
# 75   head    realistic               z_arithmetic_mean_rank  8.612533e+01
# 76   tail    realistic               z_arithmetic_mean_rank  9.943511e+01
# 77   both    realistic               z_arithmetic_mean_rank  1.313489e+02
# 78   head  pessimistic               z_arithmetic_mean_rank  8.612531e+01
# 79   tail  pessimistic               z_arithmetic_mean_rank  9.943510e+01
# 80   both  pessimistic               z_arithmetic_mean_rank  1.313489e+02
# 81   head   optimistic        adjusted_arithmetic_mean_rank  1.521688e-01
# 82   tail   optimistic        adjusted_arithmetic_mean_rank  2.194971e-02
# 83   both   optimistic        adjusted_arithmetic_mean_rank  8.595415e-02
# 84   head    realistic        adjusted_arithmetic_mean_rank  1.521689e-01
# 85   tail    realistic        adjusted_arithmetic_mean_rank  2.194975e-02
# 86   both    realistic        adjusted_arithmetic_mean_rank  8.595424e-02
# 87   head  pessimistic        adjusted_arithmetic_mean_rank  1.521691e-01
# 88   tail  pessimistic        adjusted_arithmetic_mean_rank  2.194980e-02
# 89   both  pessimistic        adjusted_arithmetic_mean_rank  8.595434e-02
# 90   head   optimistic                   standard_deviation  1.827326e+03
# 91   tail   optimistic                   standard_deviation  6.553906e+02
# 92   both   optimistic                   standard_deviation  1.490968e+03
# 93   head    realistic                   standard_deviation  1.827327e+03
# 94   tail    realistic                   standard_deviation  6.553912e+02
# 95   both    realistic                   standard_deviation  1.490968e+03
# 96   head  pessimistic                   standard_deviation  1.827327e+03
# 97   tail  pessimistic                   standard_deviation  6.553918e+02
# 98   both  pessimistic                   standard_deviation  1.490969e+03
# 99   head   optimistic                  inverse_median_rank  1.084599e-03
# 100  tail   optimistic                  inverse_median_rank  2.000000e-01
# 101  both   optimistic                  inverse_median_rank  2.941176e-02
# 102  head    realistic                  inverse_median_rank  1.084599e-03
# 103  tail    realistic                  inverse_median_rank  2.000000e-01
# 104  both    realistic                  inverse_median_rank  2.941176e-02
# 105  head  pessimistic                  inverse_median_rank  1.084599e-03
# 106  tail  pessimistic                  inverse_median_rank  2.000000e-01
# 107  both  pessimistic                  inverse_median_rank  2.941176e-02
# 108  head   optimistic                          median_rank  9.220000e+02
# 109  tail   optimistic                          median_rank  5.000000e+00
# 110  both   optimistic                          median_rank  3.400000e+01
# 111  head    realistic                          median_rank  9.220000e+02
# 112  tail    realistic                          median_rank  5.000000e+00
# 113  both    realistic                          median_rank  3.400000e+01
# 114  head  pessimistic                          median_rank  9.220000e+02
# 115  tail  pessimistic                          median_rank  5.000000e+00
# 116  both  pessimistic                          median_rank  3.400000e+01
# 117  head   optimistic          inverse_geometric_mean_rank  2.895797e-03
# 118  tail   optimistic          inverse_geometric_mean_rank  1.124998e-01
# 119  both   optimistic          inverse_geometric_mean_rank  1.804929e-02
# 120  head    realistic          inverse_geometric_mean_rank  2.895793e-03
# 121  tail    realistic          inverse_geometric_mean_rank  1.124998e-01
# 122  both    realistic          inverse_geometric_mean_rank  1.804927e-02
# 123  head  pessimistic          inverse_geometric_mean_rank  2.895791e-03
# 124  tail  pessimistic          inverse_geometric_mean_rank  1.124996e-01
# 125  both  pessimistic          inverse_geometric_mean_rank  1.804925e-02
# 126  head   optimistic                 arithmetic_mean_rank  1.368028e+03
# 127  tail   optimistic                 arithmetic_mean_rank  2.041466e+02
# 128  both   optimistic                 arithmetic_mean_rank  7.860875e+02
# 129  head    realistic                 arithmetic_mean_rank  1.368030e+03
# 130  tail    realistic                 arithmetic_mean_rank  2.041470e+02
# 131  both    realistic                 arithmetic_mean_rank  7.860884e+02
# 132  head  pessimistic                 arithmetic_mean_rank  1.368031e+03
# 133  tail  pessimistic                 arithmetic_mean_rank  2.041475e+02
# 134  both  pessimistic                 arithmetic_mean_rank  7.860893e+02
# 135  head   optimistic                z_geometric_mean_rank  5.572801e+01
# 136  tail   optimistic                z_geometric_mean_rank  5.872007e+01
# 137  both   optimistic                z_geometric_mean_rank  8.245891e+01
# 138  head    realistic                z_geometric_mean_rank  5.572800e+01
# 139  tail    realistic                z_geometric_mean_rank  5.872007e+01
# 140  both    realistic                z_geometric_mean_rank  8.245891e+01
# 141  head  pessimistic                z_geometric_mean_rank  5.572800e+01
# 142  tail  pessimistic                z_geometric_mean_rank  5.872007e+01
# 143  both  pessimistic                z_geometric_mean_rank  8.245890e+01
# 144  head   optimistic           inverse_harmonic_mean_rank  9.330911e-02
# 145  tail   optimistic           inverse_harmonic_mean_rank  3.464683e-01
# 146  both   optimistic           inverse_harmonic_mean_rank  2.198887e-01
# 147  head    realistic           inverse_harmonic_mean_rank  9.330911e-02
# 148  tail    realistic           inverse_harmonic_mean_rank  3.464684e-01
# 149  both    realistic           inverse_harmonic_mean_rank  2.198887e-01
# 150  head  pessimistic           inverse_harmonic_mean_rank  9.330911e-02
# 151  tail  pessimistic           inverse_harmonic_mean_rank  3.464683e-01
# 152  both  pessimistic           inverse_harmonic_mean_rank  2.198887e-01
# 153  head   optimistic         z_inverse_harmonic_mean_rank  5.695917e+02
# 154  tail   optimistic         z_inverse_harmonic_mean_rank  2.162815e+03
# 155  both   optimistic         z_inverse_harmonic_mean_rank  1.922014e+03
# 156  head    realistic         z_inverse_harmonic_mean_rank  5.695917e+02
# 157  tail    realistic         z_inverse_harmonic_mean_rank  2.162815e+03
# 158  both    realistic         z_inverse_harmonic_mean_rank  1.922014e+03
# 159  head  pessimistic         z_inverse_harmonic_mean_rank  5.695917e+02
# 160  tail  pessimistic         z_inverse_harmonic_mean_rank  2.162815e+03
# 161  both  pessimistic         z_inverse_harmonic_mean_rank  1.922014e+03
# 162  head   optimistic                                count  3.445000e+03
# 163  tail   optimistic                                count  3.445000e+03
# 164  both   optimistic                                count  6.890000e+03
# 165  head    realistic                                count  3.445000e+03
# 166  tail    realistic                                count  3.445000e+03
# 167  both    realistic                                count  6.890000e+03
# 168  head  pessimistic                                count  3.445000e+03
# 169  tail  pessimistic                                count  3.445000e+03
# 170  both  pessimistic                                count  6.890000e+03
# 171  head   optimistic                            hits_at_1  6.095791e-02
# 172  tail   optimistic                            hits_at_1  2.081277e-01
# 173  both   optimistic                            hits_at_1  1.345428e-01
# 174  head    realistic                            hits_at_1  6.095791e-02
# 175  tail    realistic                            hits_at_1  2.081277e-01
# 176  both    realistic                            hits_at_1  1.345428e-01
# 177  head  pessimistic                            hits_at_1  6.095791e-02
# 178  tail  pessimistic                            hits_at_1  2.081277e-01
# 179  both  pessimistic                            hits_at_1  1.345428e-01
# 180  head   optimistic                            hits_at_3  1.085631e-01
# 181  tail   optimistic                            hits_at_3  3.965167e-01
# 182  both   optimistic                            hits_at_3  2.525399e-01
# 183  head    realistic                            hits_at_3  1.085631e-01
# 184  tail    realistic                            hits_at_3  3.965167e-01
# 185  both    realistic                            hits_at_3  2.525399e-01
# 186  head  pessimistic                            hits_at_3  1.085631e-01
# 187  tail  pessimistic                            hits_at_3  3.965167e-01
# 188  both  pessimistic                            hits_at_3  2.525399e-01
# 189  head   optimistic                            hits_at_5  1.303338e-01
# 190  tail   optimistic                            hits_at_5  5.021771e-01
# 191  both   optimistic                            hits_at_5  3.162554e-01
# 192  head    realistic                            hits_at_5  1.303338e-01
# 193  tail    realistic                            hits_at_5  5.021771e-01
# 194  both    realistic                            hits_at_5  3.162554e-01
# 195  head  pessimistic                            hits_at_5  1.303338e-01
# 196  tail  pessimistic                            hits_at_5  5.021771e-01
# 197  both  pessimistic                            hits_at_5  3.162554e-01
# 198  head   optimistic                           hits_at_10  1.480406e-01
# 199  tail   optimistic                           hits_at_10  6.795356e-01
# 200  both   optimistic                           hits_at_10  4.137881e-01
# 201  head    realistic                           hits_at_10  1.480406e-01
# 202  tail    realistic                           hits_at_10  6.795356e-01
# 203  both    realistic                           hits_at_10  4.137881e-01
# 204  head  pessimistic                           hits_at_10  1.480406e-01
# 205  tail  pessimistic                           hits_at_10  6.795356e-01
# 206  both  pessimistic                           hits_at_10  4.137881e-01
# 207  head   optimistic                          z_hits_at_k  3.668387e+02
# 208  tail   optimistic                          z_hits_at_k  1.719253e+03
# 209  both   optimistic                          z_hits_at_k  1.466511e+03
# 210  head    realistic                          z_hits_at_k  3.668387e+02
# 211  tail    realistic                          z_hits_at_k  1.719253e+03
# 212  both    realistic                          z_hits_at_k  1.466511e+03
# 213  head  pessimistic                          z_hits_at_k  3.668387e+02
# 214  tail  pessimistic                          z_hits_at_k  1.719253e+03
# 215  both  pessimistic                          z_hits_at_k  1.466511e+03
# 216  head   optimistic                   adjusted_hits_at_k  1.475657e-01
# 217  tail   optimistic                   adjusted_hits_at_k  6.793632e-01
# 218  both   optimistic                   adjusted_hits_at_k  4.134670e-01
# 219  head    realistic                   adjusted_hits_at_k  1.475657e-01
# 220  tail    realistic                   adjusted_hits_at_k  6.793632e-01
# 221  both    realistic                   adjusted_hits_at_k  4.134670e-01
# 222  head  pessimistic                   adjusted_hits_at_k  1.475657e-01
# 223  tail  pessimistic                   adjusted_hits_at_k  6.793632e-01
# 224  both  pessimistic                   adjusted_hits_at_k  4.134670e-01
#
# === TransE Test-Set Metrics ===
#   Hits@1:       0.1345
#   Hits@3:       0.2525
#   Hits@10:      0.4138
#   Mean Rank:    786.09
#   MRR:          0.2199

# %%
MODEL_DIR.mkdir(parents=True, exist_ok=True)
result.save_to_directory(str(MODEL_DIR))
print(f"Model saved to {MODEL_DIR}")
print(f"\nContents:")
for p in sorted(MODEL_DIR.rglob("*")):
    if p.is_file():
        print(f"  {p.relative_to(MODEL_DIR)}  ({p.stat().st_size / 1024:.1f} KB)")
# Out:
# INFO:pykeen.triples.triples_factory:Stored TriplesFactory(num_entities=18603, num_relations=4, create_inverse_triples=False, num_triples=27560, path="/slurm/homes/pchandra/xai-knowledge-graph/data/triples/xai_kg.tsv") to file:///slurm/homes/pchandra/xai-knowledge-graph/models/transe_basline/training_triples
# INFO:pykeen.pipeline.api:Saved to directory: /slurm/homes/pchandra/xai-knowledge-graph/models/transe_basline
# Model saved to /slurm/homes/pchandra/xai-knowledge-graph/models/transe_basline
#
# Contents:
#   metadata.json  (0.0 KB)
#   results.json  (13.9 KB)
#   trained_model.pkl  (9308.1 KB)
#   training_triples/base.pth  (1.5 KB)
#   training_triples/entity_to_id.tsv.gz  (160.3 KB)
#   training_triples/numeric_triples.tsv.gz  (115.6 KB)
#   training_triples/relation_to_id.tsv.gz  (0.1 KB)
